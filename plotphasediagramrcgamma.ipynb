# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import multiprocessing
from multiprocessing import Pool
import csv
from numpy import linalg as la
#from scipy.stats import kde
#from itertools import repeat, izip
#from IPython import get_ipython;
#get_ipython().magic('reset -sf')
#plt.close('all')




if __name__ == '__main__':

	
	
	
	#Plotting

	SIZE = 15

	plt.rc('font', size=SIZE)          # controls default text sizes
	plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
	plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
	plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
	plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
	plt.rc('legend', fontsize=SIZE-5)    # legend fontsize
	plt.rc('text', usetex=True)
	plt.rcParams['axes.linewidth'] = 1.25
	plt.rcParams['legend.loc'] = 'best'

	edgewidth = 1.5
	lwidth = 1.25
	size = 7.5
	tickwidth = 1.25
	ticklength = 5
	padness = 5
	fsize = 5


	#xmin = -2.5*sigma - u
	#xmax = 2.5*sigma - u
	#ymin = -2.0
	#ymax = 0.5

	critgvec = np.genfromtxt('phasediagramcritgvec.csv', dtype = float, delimiter=',', skip_footer=0)
	rvecvec = np.genfromtxt('phasediagramrvecvec.csv', dtype = float, delimiter=',', skip_footer=0)
	gammavec = np.genfromtxt('phasediagramgammavec.csv', dtype = float, delimiter=',', skip_footer=0)
	critrvec = np.genfromtxt('phasediagramcritrvec.csv', dtype = float, delimiter=',', skip_footer=0)
	

	'''ymin = 0.1
	ymax = 10.0

	xmin = -1.0#min(np.ndarray.flatten(sigmavecth))
	xmax = 1.7'''

	gvec2 = np.linspace(min(critgvec[0]), max(critgvec[gammavec.size-1]), 100, endpoint=True)
	fig1 = plt.figure(figsize=(7.5,5))
	ax1 = fig1.add_subplot(111)
	for gammait in range(0, gammavec.size):
		#plt3 = ax1.plot(critmuvec[gammait], sigmavec[gammait], '-', color = 'k', linewidth = lwidth)
		#plt2 = ax1.plot(sigmavec2, np.sqrt(2.0)/(1.0+gammavec[gammait])*np.ones(101), '--', color = 'k', linewidth = lwidth)
		colourvec = ["b", "m", "r", "tab:orange", "y"]
		#plt1 = ax1.plot(gammavecth, lambdavecthseries, '-', linewidth = lwidth)
		mylabel = "$\Gamma = $" + str(round(gammavec[gammait], 2))
		#plt3 = ax1.plot(critsigmavec[gammait]**2*np.ones(101), np.linspace(ymin, ymax, 101, endpoint = True), '-.', color = 'k', linewidth = lwidth)
		plt0 = ax1.plot(critgvec[gammait], rvecvec[gammait], '-', color = colourvec[gammait],  markersize = (size -3.5), markeredgewidth = edgewidth, label = mylabel)
		#plt4 = ax1.plot(muvecth, edgevecth, '--', color = 'r', linewidth = lwidth)
	plt2 = ax1.plot(gvec2, critrvec[gammait]*np.ones(100) , '--', color = 'k', linewidth = lwidth)
	#plt3 = ax1.plot(np.linspace(xmin**2, xmax**2, 101, endpoint = True), np.zeros(101) , '--', color = 'k', linewidth = lwidth)
	#plt3 = ax1.plot(0.6*np.ones(101), np.linspace(ymin, ymax, 101, endpoint = True)**2.0 , '-.', color = 'k', linewidth = lwidth)
	#plt3 = ax1.plot(-0.5*np.ones(101), np.linspace(ymin, ymax, 101, endpoint = True)**2.0 , '-.', color = 'k', linewidth = lwidth)
	axes = plt.gca()
	axes.set_xlim([min(critgvec[0]),max(critgvec[gammavec.size-1])])
	ax1.set_ylim([0.5,max(rvecvec[0])])
	ax1.set_ylabel(r"$r$")
	ax1.set_xlabel(r"$\gamma$")
	handles, labels = ax1.get_legend_handles_labels()
	ax1.legend(handles, labels, loc='best',prop={'size': 14})
	#ax1.set_yscale('log')
	#handles, labels = ax1.get_legend_handles_labels()
	#ax1.legend(handles, labels, loc='best',prop={'size': 16} )
	ax1.tick_params(width = tickwidth, length = ticklength)
	ax1.tick_params(pad=padness)
	#ax1.text(0.8, 0.15, r"(a)", transform=ax1.transAxes, fontsize=fsize,
       		#verticalalignment='top', bbox=props, color='black')
	fig1.show()



#plt.savefig("phasediagramrlittlegamma.svg", format="svg")
# Out:
# <>:70: SyntaxWarning: invalid escape sequence '\G'
# <>:70: SyntaxWarning: invalid escape sequence '\G'
# /tmp/ipykernel_2057388/2529857032.py:70: SyntaxWarning: invalid escape sequence '\G'
#   mylabel = "$\Gamma = $" + str(round(gammavec[gammait], 2))
# Error in callback <function _draw_all_if_interactive at 0x7f7da3df6fc0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/hopfield_energy/lib/python3.12/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/miniforge3/envs/hopfield_energy/lib/python3.12/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
# ...

# %%
sigmavec[0]
# Out:
# array([ 0., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan,  1., nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan,  2., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan,  3., nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan,  4., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan,  5.])
